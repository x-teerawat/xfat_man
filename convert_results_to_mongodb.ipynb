# %%
import numpy as np
import pandas as pd
import os
import pymongo

# %%
### NAV
path_nav_data = f"{results_path}/{folder_name}/{file_name}"
print(path_nav_data)
nav_data = pd.read_pickle(path_nav_data)
### Buy
buy_status_data = nav_data[nav_data.status == 'buy']
# buy_commission =  buy_status_data.commission.sum()
# n_buy = len(buy_status_data)
buy_info = buy_status_data[["open", "commission"]].reset_index()
buy_info.columns = ["buyTime", "buyPirce", "buyCom"] # Rename columns
buy_info['buyCond'] = "tf15s_hl"
buy_info['buyTime'] = [pd.to_datetime(i).strftime("%Y-%m-%d %H-%M-%S") for i in buy_info.buyTime.values]


### Sell
sell_status_data = nav_data[nav_data.status == 'sell']
# sell_commission =  sell_status_data.commission.sum()
# last_nav = sell_status_data.nav[-1]
sell_info = sell_status_data[["open", "commission"]].reset_index()
sell_info.columns = ["sellTime", "sellPirce", "sellCom"] # Rename columns
sell_info['sellTime'] = [pd.to_datetime(i).strftime("%Y-%m-%d %H-%M-%S") for i in sell_info.sellTime.values]
if sell_strategy == "1":
    sell_condition = "tf15s_lh"
    robot_id = "xrob001"
    stg_id = "xstg001"
elif sell_strategy == "2":
    sell_condition = "tf15s_ema12x<24"
    robot_id = "xrob002"
    stg_id = "xstg002"
elif sell_strategy == "3":
    sell_condition = "tf15s_lh_or_tf15s_ema12x<24"
    robot_id = "xrob003"
    stg_id = "xstg003"
elif sell_strategy == "4":
    sell_condition = "tf15s_ema12x<24_and_tf15s_lh"
    robot_id = "xrob004"
    stg_id = "xstg004"
sell_info['sellCond'] = sell_condition

### Buy and sell info
buy_sell_info = pd.concat([buy_info, sell_info], axis=1)
buy_sell_info.index.name = "orderId"
buy_sell_info.reset_index(inplace=True)
buy_sell_info['orderId'] = buy_sell_info.orderId+1
buy_sell_info['robotId'] = robot_id
buy_sell_info['strategyId'] = stg_id
buy_sell_info['pnl'] = ((buy_sell_info.sellPirce/buy_sell_info.buyPirce)-1)*100
buy_sell_info['com'] = buy_sell_info.buyCom + buy_sell_info.sellCom
buy_sell_info.drop(columns=["buyCom", "sellCom"], inplace=True)
buy_sell_info['pnlPercentCom'] = buy_sell_info.pnl/buy_sell_info.com
buy_sell_info = buy_sell_info[["orderId", "robotId", "strategyId", "buyTime", "buyPirce", "buyCond", "sellTime", "sellPirce", "sellCond", "pnl", "com", "pnlPercentCom"]] # Reorder columns

for o_i, r_i, s_i, b_t, b_p, b_c, s_t, s_p, s_c in zip(
    buy_sell_info.orderId.values,
    buy_sell_info.robotId.values,
    buy_sell_info.strategyId.values,
    buy_sell_info.buyTime.values,
    buy_sell_info.buyPirce.values,
    buy_sell_info.buyCond.values,
    buy_sell_info.sellTime.values,
    buy_sell_info.sellPirce.values,
    buy_sell_info.sellCond.values
    ):

# %%
lst_test_date = []
lst_strategies = []
lst_nav = []
lst_number_of_buy_and_sell = []
lst_total_buy_commission = []
lst_total_sell_commission = []
lst_interfaces = []

lst_buy_sell_info = []

round_nth = 0

results_path = "/Users/x/Documents/GitHub/teex/results"
for folder_name in os.listdir(f"{results_path}"):
    if folder_name.startswith("plot"):
        for file_name in os.listdir(f"{results_path}/{folder_name}"):
            if file_name.startswith("nav_data"):
                split_txt = folder_name.split("__")
                test_date = split_txt[3].split("_")[-1]
                sell_strategy = split_txt[2][-1]

                ### NAV
                path_nav_data = f"{results_path}/{folder_name}/{file_name}"
                nav_data = pd.read_pickle(path_nav_data)
                ### Buy
                buy_status_data = nav_data[nav_data.status == 'buy']
                # buy_commission =  buy_status_data.commission.sum()
                # n_buy = len(buy_status_data)
                buy_info = buy_status_data[["open", "commission"]].reset_index()
                buy_info.columns = ["buyTime", "buyPirce", "buyCom"] # Rename columns
                buy_info['buyCond'] = "tf15s_hl"
                buy_info['buyTime'] = [pd.to_datetime(i).strftime("%Y-%m-%d %H-%M-%S") for i in buy_info.buyTime.values]
                

                ### Sell
                sell_status_data = nav_data[nav_data.status == 'sell']
                # sell_commission =  sell_status_data.commission.sum()
                # last_nav = sell_status_data.nav[-1]
                sell_info = sell_status_data[["open", "commission"]].reset_index()
                sell_info.columns = ["sellTime", "sellPirce", "sellCom"] # Rename columns
                sell_info['sellTime'] = [pd.to_datetime(i).strftime("%Y-%m-%d %H-%M-%S") for i in sell_info.sellTime.values]
                if sell_strategy == "1":
                    sell_condition = "tf15s_lh"
                    robot_id = "xrob001"
                    stg_id = "xstg001"
                elif sell_strategy == "2":
                    sell_condition = "tf15s_ema12x<24"
                    robot_id = "xrob002"
                    stg_id = "xstg002"
                elif sell_strategy == "3":
                    sell_condition = "tf15s_lh_or_tf15s_ema12x<24"
                    robot_id = "xrob003"
                    stg_id = "xstg003"
                elif sell_strategy == "4":
                    sell_condition = "tf15s_ema12x<24_and_tf15s_lh"
                    robot_id = "xrob004"
                    stg_id = "xstg004"
                sell_info['sellCond'] = sell_condition

                ### Buy and sell info
                buy_sell_info = pd.concat([buy_info, sell_info], axis=1)
                buy_sell_info.index.name = "orderId"
                buy_sell_info.reset_index(inplace=True)
                buy_sell_info['orderId'] = buy_sell_info.orderId+1
                buy_sell_info['robotId'] = robot_id
                buy_sell_info['strategyId'] = stg_id
                buy_sell_info['pnl'] = ((buy_sell_info.sellPirce/buy_sell_info.buyPirce)-1)*100
                buy_sell_info['com'] = buy_sell_info.buyCom + buy_sell_info.sellCom
                buy_sell_info.drop(columns=["buyCom", "sellCom"], inplace=True)
                buy_sell_info['pnlPercentCom'] = buy_sell_info.pnl/buy_sell_info.com
                buy_sell_info = buy_sell_info[["orderId", "robotId", "strategyId", "buyTime", "buyPirce", "buyCond", "sellTime", "sellPirce", "sellCond", "pnl", "com", "pnlPercentCom"]] # Reorder columns

                for o_i, r_i, s_i, b_t, b_p, b_c, s_t, s_p, s_c in zip(
                    buy_sell_info.orderId.values,
                    buy_sell_info.robotId.values,
                    buy_sell_info.strategyId.values,
                    buy_sell_info.buyTime.values,
                    buy_sell_info.buyPirce.values,
                    buy_sell_info.buyCond.values,
                    buy_sell_info.sellTime.values,
                    buy_sell_info.sellPirce.values,
                    buy_sell_info.sellCond.values
                    ):

                    lst_buy_sell_info.append({"orderId": int(o_i), "robotId": r_i, "strategyId": s_i, "buyTime": b_t, "buyPirce": np.round(b_p, 2), "buyCond": b_c, "sellTime": s_t, "sellPirce": np.round(s_p, 2), "sellCond": s_c}) # .strftime("%Y-%M-%d %H-%m-%s") # 
                    # collection.insert_one({"orderId": o_i}) # , "robotId": r_i, "strategyId": s_i, "buyTime": b_t, "buyPirce": np.round(b_p, 2), "buyCond": b_c, "sellTime": s_t, "sellPirce": np.round(s_p, 2), "sellCond": s_c

# %%
### Connect to MongoDB
mongo_client = pymongo.MongoClient("mongodb://ubuntu:ubuntu@172.17.100.47:27017/")

db = mongo_client["teerawat_xu"] # Create a folder
collection = db["xwealth"] # Create a sub-folder

# %%
### Insert data to MongoDB
collection.insert_many(lst_buy_sell_info)
# Out:
# InsertManyResult([ObjectId('65c23265a7754967e40d6c60'), ObjectId('65c232baa7754967e40d6c62'), ObjectId('65c232baa7754967e40d6c63'), ObjectId('65c232baa7754967e40d6c64'), ObjectId('65c232baa7754967e40d6c65'), ObjectId('65c232baa7754967e40d6c66'), ObjectId('65c232baa7754967e40d6c67'), ObjectId('65c232baa7754967e40d6c68'), ObjectId('65c232baa7754967e40d6c69'), ObjectId('65c232baa7754967e40d6c6a'), ObjectId('65c232baa7754967e40d6c6b'), ObjectId('65c232baa7754967e40d6c6c'), ObjectId('65c232baa7754967e40d6c6d'), ObjectId('65c232baa7754967e40d6c6e'), ObjectId('65c232baa7754967e40d6c6f'), ObjectId('65c232baa7754967e40d6c70'), ObjectId('65c232baa7754967e40d6c71'), ObjectId('65c232baa7754967e40d6c72'), ObjectId('65c232baa7754967e40d6c73'), ObjectId('65c232baa7754967e40d6c74'), ObjectId('65c232baa7754967e40d6c75'), ObjectId('65c232baa7754967e40d6c76'), ObjectId('65c232baa7754967e40d6c77'), ObjectId('65c232baa7754967e40d6c78'), ObjectId('65c232baa7754967e40d6c79'), ObjectId('65c232baa7754967e40d6c7a'), ObjectId('65c232baa7754967e40d6c7b'), ObjectId('65c232baa7754967e40d6c7c'), ObjectId('65c232baa7754967e40d6c7d'), ObjectId('65c232baa7754967e40d6c7e'), ObjectId('65c232baa7754967e40d6c7f'), ObjectId('65c232baa7754967e40d6c80'), ObjectId('65c232baa7754967e40d6c81'), ObjectId('65c232baa7754967e40d6c82'), ObjectId('65c232baa7754967e40d6c83'), ObjectId('65c232baa7754967e40d6c84'), ObjectId('65c232baa7754967e40d6c85'), ObjectId('65c232baa7754967e40d6c86'), ObjectId('65c232baa7754967e40d6c87'), ObjectId('65c232baa7754967e40d6c88'), ObjectId('65c232baa7754967e40d6c89'), ObjectId('65c232baa7754967e40d6c8a'), ObjectId('65c232baa7754967e40d6c8b'), ObjectId('65c232baa7754967e40d6c8c'), ObjectId('65c232baa7754967e40d6c8d'), ObjectId('65c232baa7754967e40d6c8e'), ObjectId('65c232baa7754967e40d6c8f'), ObjectId('65c232baa7754967e40d6c90'), ObjectId('65c232baa7754967e40d6c91'), ObjectId('65c232baa7754967e40d6c92'), ObjectId('65c232baa7754967e40d6c93'), ObjectId('65c232baa7754967e40d6c94'), ObjectId('65c232baa7754967e40d6c95'), ObjectId('65c232baa7754967e40d6c96'), ObjectId('65c232baa7754967e40d6c97'), ObjectId('65c232baa7754967e40d6c98'), ObjectId('65c232baa7754967e40d6c99'), ObjectId('65c232baa7754967e40d6c9a'), ObjectId('65c232baa7754967e40d6c9b'), ObjectId('65c232baa7754967e40d6c9c'), ObjectId('65c232baa7754967e40d6c9d'), ObjectId('65c232baa7754967e40d6c9e'), ObjectId('65c232baa7754967e40d6c9f'), ObjectId('65c232baa7754967e40d6ca0'), ObjectId('65c232baa7754967e40d6ca1'), ObjectId('65c232baa7754967e40d6ca2'), ObjectId('65c232baa7754967e40d6ca3'), ObjectId('65c232baa7754967e40d6ca4'), ObjectId('65c232baa7754967e40d6ca5'), ObjectId('65c232baa7754967e40d6ca6'), ObjectId('65c232baa7754967e40d6ca7'), ObjectId('65c232baa7754967e40d6ca8'), ObjectId('65c232baa7754967e40d6ca9'), ObjectId('65c232baa7754967e40d6caa'), ObjectId('65c232baa7754967e40d6cab'), ObjectId('65c232baa7754967e40d6cac'), ObjectId('65c232baa7754967e40d6cad'), ObjectId('65c232baa7754967e40d6cae'), ObjectId('65c232baa7754967e40d6caf'), ObjectId('65c232baa7754967e40d6cb0'), ObjectId('65c232baa7754967e40d6cb1'), ObjectId('65c232baa7754967e40d6cb2'), ObjectId('65c232baa7754967e40d6cb3'), ObjectId('65c232baa7754967e40d6cb4'), ObjectId('65c232baa7754967e40d6cb5'), ObjectId('65c232baa7754967e40d6cb6'), ObjectId('65c232baa7754967e40d6cb7'), ObjectId('65c232baa7754967e40d6cb8'), ObjectId('65c232baa7754967e40d6cb9'), ObjectId('65c232baa7754967e40d6cba'), ObjectId('65c232baa7754967e40d6cbb'), ObjectId('65c232baa7754967e40d6cbc'), ObjectId('65c232baa7754967e40d6cbd'), ObjectId('65c232baa7754967e40d6cbe'), ObjectId('65c232baa7754967e40d6cbf'), ObjectId('65c232baa7754967e40d6cc0'), ObjectId('65c232baa7754967e40d6cc1'), ObjectId('65c232baa7754967e40d6cc2'), ObjectId('65c232baa7754967e40d6cc3'), ObjectId('65c232baa7754967e40d6cc4'), ObjectId('65c232baa7754967e40d6cc5'), ObjectId('65c232baa7754967e40d6cc6'), ObjectId('65c232baa7754967e40d6cc7'), ObjectId('65c232baa7754967e40d6cc8'), ObjectId('65c232baa7754967e40d ...

# %%
for i in collection.find():
    print(i)
# Out:
# {'_id': ObjectId('65c23265a7754967e40d6c60'), 'orderId': 1, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 25, 9, 52), 'buyPirce': 56.98, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 26, 0, 53), 'sellPirce': 56.88, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c62'), 'orderId': 2, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 25, 10, 8), 'buyPirce': 56.82, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 27, 7, 12), 'sellPirce': 57.02, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c63'), 'orderId': 3, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 26, 16, 18), 'buyPirce': 57.02, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 27, 8, 19), 'sellPirce': 57.12, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c64'), 'orderId': 4, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 27, 7, 24), 'buyPirce': 57.26, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 26, 16, 26), 'sellPirce': 57.3, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c65'), 'orderId': 5, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 27, 7, 31), 'buyPirce': 57.31, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 25, 10, 33), 'sellPirce': 57.26, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c66'), 'orderId': 6, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 27, 7, 45), 'buyPirce': 57.15, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 26, 1, 47), 'sellPirce': 57.2, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c67'), 'orderId': 7, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 25, 11, 9), 'buyPirce': 56.99, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 26, 2, 10), 'sellPirce': 57.09, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c68'), 'orderId': 8, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 27, 8, 17), 'buyPirce': 57.21, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 25, 11, 22), 'sellPirce': 57.25, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c69'), 'orderId': 9, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 26, 18, 16), 'buyPirce': 56.94, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 25, 12, 19), 'sellPirce': 56.99, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c6a'), 'orderId': 10, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 26, 3, 28), 'buyPirce': 56.91, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 25, 12, 31), 'sellPirce': 56.76, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c6b'), 'orderId': 11, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 26, 3, 42), 'buyPirce': 56.62, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 27, 9, 42), 'sellPirce': 56.62, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c6c'), 'orderId': 12, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 26, 4, 4), 'buyPirce': 56.65, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 25, 13, 6), 'sellPirce': 56.7, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c6d'), 'orderId': 13, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 26, 4, 9), 'buyPirce': 56.73, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 25, 13, 11), 'sellPirce': 56.67, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c6e'), 'orderId': 14, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 26, 4, 30), 'buyPirce': 56.26, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 27, 10, 30), 'sellPirce': 56.28, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c6f'), 'orderId': 15, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 25, 13, 44), 'buyPirce': 56.41, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 25, 13, 48), 'sellPirce': 56.4, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c70'), 'orderId': 16, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 26, 19, 50), 'buyPirce': 56.37, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 26, 19, 51), 'sellPirce': 56.33, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c71'), 'orderId': 17, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 26, 20, 5), 'buyPirce': 55.73, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 26, 20, 9), 'sellPirce': 55.6, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c72'), 'orderId': 18, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 26, 20, 14), 'buyPirce': 55.73, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 25, 14, 17), 'sellPirce': 55.73, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c73'), 'orderId': 19, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 26, 20, 23), 'buyPirce': 55.74, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 25, 14, 24), 'sellPirce': 55.69, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c74'), 'orderId': 20, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 26, 5, 33), 'buyPirce': 55.87, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 27, 11, 33), 'sellPirce': 55.88, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c75'), 'orderId': 21, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 26, 20, 36), 'buyPirce': 55.89, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 26, 5, 37), 'sellPirce': 55.74, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c76'), 'orderId': 22, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 26, 6, 47), 'buyPirce': 55.86, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 26, 5, 48), 'sellPirce': 55.78, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c77'), 'orderId': 23, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 26, 21, 6), 'buyPirce': 56.13, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 26, 6, 10), 'sellPirce': 56.17, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c78'), 'orderId': 24, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 27, 12, 12), 'buyPirce': 56.13, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 26, 6, 13), 'sellPirce': 56.08, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c79'), 'orderId': 25, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 26, 21, 37), 'buyPirce': 56.22, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 27, 12, 38), 'sellPirce': 56.16, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c7a'), 'orderId': 26, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 25, 15, 52), 'buyPirce': 56.23, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 26, 6, 54), 'sellPirce': 56.27, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c7b'), 'orderId': 1, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 23, 15, 36), 'buyPirce': 55.75, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 23, 15, 37), 'sellPirce': 55.66, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c7c'), 'orderId': 2, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 23, 15, 57), 'buyPirce': 55.46, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 23, 15, 58), 'sellPirce': 55.44, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c7d'), 'orderId': 3, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 22, 10, 11), 'buyPirce': 55.39, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 23, 16, 12), 'sellPirce': 55.38, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c7e'), 'orderId': 4, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 24, 7, 17), 'buyPirce': 55.44, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 23, 1, 18), 'sellPirce': 55.43, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c7f'), 'orderId': 5, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 24, 7, 34), 'buyPirce': 54.85, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 24, 7, 35), 'sellPirce': 54.87, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c80'), 'orderId': 6, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 22, 10, 41), 'buyPirce': 54.89, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 24, 7, 41), 'sellPirce': 54.94, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c81'), 'orderId': 7, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 22, 11, 4), 'buyPirce': 54.63, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 23, 17, 9), 'sellPirce': 54.8, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c82'), 'orderId': 8, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 23, 17, 18), 'buyPirce': 54.92, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 23, 17, 19), 'sellPirce': 54.96, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c83'), 'orderId': 9, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 23, 17, 28), 'buyPirce': 55.02, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 24, 8, 29), 'sellPirce': 55.07, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c84'), 'orderId': 10, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 22, 11, 37), 'buyPirce': 55.09, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 23, 17, 37), 'sellPirce': 55.05, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c85'), 'orderId': 11, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 23, 3, 1), 'buyPirce': 55.17, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 23, 3, 4), 'sellPirce': 55.11, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c86'), 'orderId': 12, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 24, 10, 16), 'buyPirce': 54.89, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 22, 13, 20), 'sellPirce': 54.97, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c87'), 'orderId': 13, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 23, 18, 26), 'buyPirce': 55.0, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 23, 3, 28), 'sellPirce': 54.98, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c88'), 'orderId': 14, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 24, 10, 40), 'buyPirce': 54.75, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 24, 11, 41), 'sellPirce': 54.78, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c89'), 'orderId': 15, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 23, 5, 33), 'buyPirce': 54.77, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 23, 20, 35), 'sellPirce': 54.69, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c8a'), 'orderId': 16, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 23, 6, 1), 'buyPirce': 54.76, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 24, 12, 1), 'sellPirce': 54.75, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c8b'), 'orderId': 17, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 22, 16, 13), 'buyPirce': 54.83, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 23, 6, 14), 'sellPirce': 54.88, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c8c'), 'orderId': 1, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 6, 0, 33), 'buyPirce': 45.97, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 5, 9, 37), 'sellPirce': 46.16, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c8d'), 'orderId': 2, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 7, 6, 37), 'buyPirce': 46.12, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 6, 0, 38), 'sellPirce': 46.19, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c8e'), 'orderId': 3, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 5, 9, 44), 'buyPirce': 46.01, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 6, 15, 45), 'sellPirce': 46.08, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c8f'), 'orderId': 4, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 6, 15, 48), 'buyPirce': 46.12, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 5, 9, 50), 'sellPirce': 46.18, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c90'), 'orderId': 5, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 6, 0, 53), 'buyPirce': 46.17, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 6, 0, 54), 'sellPirce': 46.22, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c91'), 'orderId': 6, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 6, 1, 7), 'buyPirce': 46.66, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 7, 7, 10), 'sellPirce': 46.67, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c92'), 'orderId': 7, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 5, 10, 11), 'buyPirce': 46.65, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 7, 7, 30), 'sellPirce': 46.53, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c93'), 'orderId': 8, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 5, 10, 27), 'buyPirce': 46.61, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 7, 7, 40), 'sellPirce': 46.68, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c94'), 'orderId': 9, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 5, 10, 40), 'buyPirce': 46.74, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 7, 8, 5), 'sellPirce': 46.84, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c95'), 'orderId': 10, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 6, 2, 4), 'buyPirce': 46.83, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 5, 12, 1), 'sellPirce': 46.38, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c96'), 'orderId': 11, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 6, 2, 58), 'buyPirce': 46.43, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 5, 12, 19), 'sellPirce': 46.06, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c97'), 'orderId': 12, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 7, 9, 17), 'buyPirce': 46.09, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 6, 3, 36), 'sellPirce': 45.96, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c98'), 'orderId': 13, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 6, 18, 33), 'buyPirce': 45.9, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 6, 3, 41), 'sellPirce': 46.08, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c99'), 'orderId': 14, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 6, 5, 39), 'buyPirce': 46.02, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 7, 9, 44), 'sellPirce': 46.11, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c9a'), 'orderId': 15, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 6, 3, 43), 'buyPirce': 46.05, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 5, 12, 49), 'sellPirce': 46.05, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c9b'), 'orderId': 16, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 5, 12, 47), 'buyPirce': 46.06, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 7, 10, 41), 'sellPirce': 46.26, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c9c'), 'orderId': 17, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 6, 19, 40), 'buyPirce': 46.24, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 5, 13, 51), 'sellPirce': 46.22, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c9d'), 'orderId': 18, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 7, 10, 48), 'buyPirce': 46.25, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 6, 23, 38), 'sellPirce': 46.09, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c9e'), 'orderId': 19, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 7, 12, 37), 'buyPirce': 46.07, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 6, 5, 52), 'sellPirce': 45.72, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6c9f'), 'orderId': 20, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 5, 14, 48), 'buyPirce': 45.93, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 6, 21, 18), 'sellPirce': 45.64, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6ca0'), 'orderId': 21, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 6, 8, 16), 'buyPirce': 45.7, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 7, 13, 42), 'sellPirce': 45.68, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6ca1'), 'orderId': 22, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 7, 12, 40), 'buyPirce': 45.62, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 6, 21, 49), 'sellPirce': 45.85, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6ca2'), 'orderId': 23, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 6, 21, 46), 'buyPirce': 45.83, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 6, 22, 53), 'sellPirce': 45.92, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6ca3'), 'orderId': 24, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 6, 21, 51), 'buyPirce': 45.88, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 6, 21, 58), 'sellPirce': 45.97, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6ca5'), 'orderId': 1, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 12, 9, 38), 'buyPirce': 50.64, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 14, 6, 40), 'sellPirce': 50.76, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6ca6'), 'orderId': 2, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 12, 9, 47), 'buyPirce': 50.89, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 14, 6, 47), 'sellPirce': 50.95, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6ca7'), 'orderId': 3, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 12, 10, 9), 'buyPirce': 50.56, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 13, 16, 12), 'sellPirce': 50.37, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6ca8'), 'orderId': 4, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 12, 10, 17), 'buyPirce': 50.32, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 13, 1, 20), 'sellPirce': 50.16, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6ca9'), 'orderId': 5, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 13, 1, 22), 'buyPirce': 50.19, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 12, 10, 28), 'sellPirce': 50.26, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6caa'), 'orderId': 6, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 14, 7, 33), 'buyPirce': 50.42, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 13, 1, 35), 'sellPirce': 50.4, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6cab'), 'orderId': 7, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 12, 10, 57), 'buyPirce': 49.96, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 13, 1, 58), 'sellPirce': 50.01, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6cac'), 'orderId': 8, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 13, 17, 0), 'buyPirce': 50.07, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 13, 2, 6), 'sellPirce': 50.19, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6cad'), 'orderId': 9, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 14, 8, 11), 'buyPirce': 50.4, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 14, 8, 14), 'sellPirce': 50.42, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6cae'), 'orderId': 10, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 14, 8, 19), 'buyPirce': 50.48, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 14, 8, 21), 'sellPirce': 50.44, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6caf'), 'orderId': 11, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 13, 3, 24), 'buyPirce': 50.15, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 13, 3, 25), 'sellPirce': 50.06, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6cb0'), 'orderId': 12, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 12, 16, 19), 'buyPirce': 50.49, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 14, 11, 19), 'sellPirce': 50.48, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6cb1'), 'orderId': 13, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 13, 5, 43), 'buyPirce': 50.2, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 13, 20, 51), 'sellPirce': 50.26, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6cb2'), 'orderId': 14, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 12, 14, 52), 'buyPirce': 50.26, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 13, 5, 55), 'sellPirce': 50.18, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6cb3'), 'orderId': 15, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 13, 6, 51), 'buyPirce': 50.31, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 14, 12, 51), 'sellPirce': 50.28, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6cb4'), 'orderId': 1, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 19, 15, 31), 'buyPirce': 50.98, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 18, 9, 33), 'sellPirce': 50.9, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cb5'), 'orderId': 2, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 18, 9, 42), 'buyPirce': 50.98, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 19, 15, 43), 'sellPirce': 50.96, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cb6'), 'orderId': 3, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 18, 9, 58), 'buyPirce': 50.88, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 19, 0, 59), 'sellPirce': 50.87, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cb7'), 'orderId': 4, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 18, 10, 1), 'buyPirce': 50.94, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 20, 7, 1), 'sellPirce': 50.84, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cb8'), 'orderId': 5, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 19, 1, 9), 'buyPirce': 50.62, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 19, 1, 15), 'sellPirce': 50.79, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cb9'), 'orderId': 6, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 19, 1, 19), 'buyPirce': 50.83, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 19, 16, 26), 'sellPirce': 50.87, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cba'), 'orderId': 7, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 19, 2, 28), 'buyPirce': 50.89, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 19, 16, 29), 'sellPirce': 50.92, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cbb'), 'orderId': 8, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 20, 7, 31), 'buyPirce': 50.96, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 19, 1, 40), 'sellPirce': 51.14, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cbc'), 'orderId': 9, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 20, 7, 51), 'buyPirce': 51.18, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 20, 7, 52), 'sellPirce': 51.24, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cbd'), 'orderId': 10, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 19, 18, 12), 'buyPirce': 51.07, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 19, 19, 14), 'sellPirce': 51.12, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cbe'), 'orderId': 11, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 19, 18, 22), 'buyPirce': 51.27, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 20, 8, 25), 'sellPirce': 51.33, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cbf'), 'orderId': 12, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 19, 2, 33), 'buyPirce': 51.44, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 19, 2, 38), 'sellPirce': 51.49, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cc0'), 'orderId': 13, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 18, 11, 55), 'buyPirce': 51.36, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 18, 12, 6), 'sellPirce': 50.85, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cc1'), 'orderId': 14, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 19, 3, 18), 'buyPirce': 50.84, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 19, 4, 43), 'sellPirce': 50.74, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cc2'), 'orderId': 15, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 18, 12, 47), 'buyPirce': 50.78, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 18, 12, 49), 'sellPirce': 50.83, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cc3'), 'orderId': 16, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 19, 19, 29), 'buyPirce': 50.27, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 18, 13, 31), 'sellPirce': 50.32, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cc4'), 'orderId': 17, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 19, 19, 46), 'buyPirce': 50.67, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 19, 4, 49), 'sellPirce': 50.75, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cc5'), 'orderId': 18, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 19, 5, 18), 'buyPirce': 51.13, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 20, 11, 22), 'sellPirce': 51.18, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cc6'), 'orderId': 19, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 19, 5, 27), 'buyPirce': 51.32, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 19, 20, 48), 'sellPirce': 51.28, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cc7'), 'orderId': 20, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 19, 5, 56), 'buyPirce': 51.45, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 19, 5, 57), 'sellPirce': 51.53, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cc9'), 'orderId': 1, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 2, 10, 3), 'buyPirce': 48.63, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 2, 10, 4), 'sellPirce': 48.64, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6cca'), 'orderId': 2, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 3, 16, 14), 'buyPirce': 48.42, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 2, 10, 15), 'sellPirce': 48.37, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6ccb'), 'orderId': 3, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 2, 10, 26), 'buyPirce': 48.34, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 3, 16, 26), 'sellPirce': 48.27, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6ccc'), 'orderId': 4, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 3, 1, 46), 'buyPirce': 48.11, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 2, 11, 49), 'sellPirce': 47.99, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6ccd'), 'orderId': 5, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 3, 17, 5), 'buyPirce': 48.18, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 2, 11, 7), 'sellPirce': 48.2, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6cce'), 'orderId': 6, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 3, 2, 13), 'buyPirce': 48.34, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 3, 2, 15), 'sellPirce': 48.4, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6ccf'), 'orderId': 7, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 3, 18, 22), 'buyPirce': 48.41, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 2, 12, 23), 'sellPirce': 48.46, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6cd0'), 'orderId': 8, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 3, 3, 11), 'buyPirce': 48.65, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 4, 9, 12), 'sellPirce': 48.65, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6cd1'), 'orderId': 9, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 3, 3, 43), 'buyPirce': 48.61, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 3, 3, 46), 'sellPirce': 48.56, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6cd2'), 'orderId': 10, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 2, 13, 28), 'buyPirce': 48.26, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 3, 5, 31), 'sellPirce': 48.28, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6cd3'), 'orderId': 11, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 3, 5, 32), 'buyPirce': 47.89, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 3, 5, 37), 'sellPirce': 47.89, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6cd4'), 'orderId': 12, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 3, 21, 21), 'buyPirce': 47.38, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 4, 12, 22), 'sellPirce': 47.38, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6cd5'), 'orderId': 13, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 3, 21, 34), 'buyPirce': 47.5, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 3, 21, 36), 'sellPirce': 47.44, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d6cd6'), 'orderId': 1, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 10, 6, 42), 'buyPirce': 46.87, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 9, 0, 44), 'sellPirce': 46.9, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cd7'), 'orderId': 2, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 8, 9, 48), 'buyPirce': 47.04, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 8, 9, 52), 'sellPirce': 47.06, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cd8'), 'orderId': 3, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 9, 0, 56), 'buyPirce': 47.01, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 9, 16, 3), 'sellPirce': 47.31, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cd9'), 'orderId': 4, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 9, 17, 7), 'buyPirce': 47.41, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 8, 10, 10), 'sellPirce': 47.44, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cda'), 'orderId': 5, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 9, 1, 21), 'buyPirce': 47.36, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 10, 8, 22), 'sellPirce': 47.45, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cdb'), 'orderId': 6, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 9, 17, 51), 'buyPirce': 47.66, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 9, 17, 18), 'sellPirce': 47.56, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cdc'), 'orderId': 7, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 10, 9, 22), 'buyPirce': 47.57, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 10, 9, 2), 'sellPirce': 47.82, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cdd'), 'orderId': 8, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 9, 18, 4), 'buyPirce': 47.82, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 10, 9, 12), 'sellPirce': 47.88, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cde'), 'orderId': 9, 'robotId': 'xrob001', 'strategyId': 'xstg001', 'buyTime': datetime.datetime(2024, 1, 8, 15, 0), 'buyPirce': 48.66, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 9, 7, 57), 'sellPirce': 48.78, 'sellCond': 'tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cdf'), 'orderId': 1, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 11, 6, 35), 'buyPirce': 47.94, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 11, 7, 19), 'sellPirce': 48.33, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6ce0'), 'orderId': 2, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 10, 16, 25), 'buyPirce': 48.3, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 10, 16, 33), 'sellPirce': 48.14, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6ce1'), 'orderId': 3, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 9, 12, 42), 'buyPirce': 48.3, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 11, 7, 43), 'sellPirce': 48.35, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6ce2'), 'orderId': 4, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 10, 2, 47), 'buyPirce': 48.29, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 11, 7, 47), 'sellPirce': 48.32, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6ce3'), 'orderId': 5, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 10, 17, 5), 'buyPirce': 48.34, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 10, 17, 6), 'sellPirce': 48.42, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6ce4'), 'orderId': 6, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 10, 17, 8), 'buyPirce': 48.43, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 10, 2, 10), 'sellPirce': 48.46, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6ce5'), 'orderId': 7, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 9, 11, 18), 'buyPirce': 48.6, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 9, 11, 19), 'sellPirce': 48.62, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6ce6'), 'orderId': 8, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 11, 8, 25), 'buyPirce': 48.63, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 10, 2, 31), 'sellPirce': 48.68, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6ce7'), 'orderId': 9, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 10, 17, 36), 'buyPirce': 48.66, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 11, 8, 37), 'sellPirce': 48.7, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6ce8'), 'orderId': 10, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 9, 12, 12), 'buyPirce': 49.09, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 11, 10, 3), 'sellPirce': 49.37, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6ce9'), 'orderId': 11, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 9, 13, 40), 'buyPirce': 48.95, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 9, 17, 17), 'sellPirce': 49.04, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cea'), 'orderId': 12, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 10, 5, 19), 'buyPirce': 49.06, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 9, 14, 22), 'sellPirce': 49.09, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6ceb'), 'orderId': 13, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 10, 20, 23), 'buyPirce': 49.05, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 10, 20, 29), 'sellPirce': 48.96, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cec'), 'orderId': 14, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 11, 12, 2), 'buyPirce': 49.05, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 10, 21, 4), 'sellPirce': 49.12, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6ced'), 'orderId': 15, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 10, 6, 23), 'buyPirce': 49.1, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 10, 6, 43), 'sellPirce': 48.84, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cee'), 'orderId': 16, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 11, 12, 56), 'buyPirce': 49.08, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 10, 6, 57), 'sellPirce': 49.11, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cef'), 'orderId': 1, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 20, 0, 42), 'buyPirce': 52.32, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 20, 0, 53), 'sellPirce': 52.4, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cf0'), 'orderId': 2, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 20, 0, 58), 'buyPirce': 52.41, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 20, 0, 59), 'sellPirce': 52.48, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cf1'), 'orderId': 3, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 20, 1, 1), 'buyPirce': 52.52, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 19, 10, 2), 'sellPirce': 52.54, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cf2'), 'orderId': 4, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 20, 16, 5), 'buyPirce': 52.47, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 20, 16, 43), 'sellPirce': 52.64, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cf3'), 'orderId': 5, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 21, 7, 46), 'buyPirce': 52.6, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 21, 7, 47), 'sellPirce': 52.64, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cf4'), 'orderId': 6, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 21, 7, 49), 'buyPirce': 52.56, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 20, 1, 59), 'sellPirce': 52.62, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cf5'), 'orderId': 7, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 20, 17, 18), 'buyPirce': 52.94, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 20, 2, 57), 'sellPirce': 52.91, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cf6'), 'orderId': 8, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 19, 12, 4), 'buyPirce': 52.91, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 20, 3, 5), 'sellPirce': 52.98, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cf7'), 'orderId': 9, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 20, 18, 28), 'buyPirce': 53.1, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 20, 3, 30), 'sellPirce': 53.17, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cf8'), 'orderId': 10, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 21, 9, 32), 'buyPirce': 53.28, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 20, 18, 34), 'sellPirce': 53.3, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cf9'), 'orderId': 11, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 20, 3, 39), 'buyPirce': 53.38, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 21, 11, 20), 'sellPirce': 53.72, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cfa'), 'orderId': 12, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 20, 20, 27), 'buyPirce': 53.72, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 20, 5, 35), 'sellPirce': 54.22, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cfb'), 'orderId': 13, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 21, 11, 42), 'buyPirce': 54.33, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 20, 20, 44), 'sellPirce': 54.3, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# {'_id': ObjectId('65c232baa7754967e40d6cfc'), 'orderId': 14, 'robotId': 'xrob004', 'strategyId': 'xstg004', 'buyTime': datetime.datetime(2024, 1, 20, 21, 5), 'buyPirce': 54.51, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 20, 21, 7), 'sellPirce': 54.58, 'sellCond': 'tf15s_ema12x<24_and_tf15s_lh'}
# ...
# {'_id': ObjectId('65c232baa7754967e40d7090'), 'orderId': 22, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 13, 12, 50), 'buyPirce': 50.18, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 13, 12, 51), 'sellPirce': 50.06, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d7091'), 'orderId': 1, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 27, 15, 35), 'buyPirce': 55.66, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 27, 15, 37), 'sellPirce': 55.51, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d7092'), 'orderId': 2, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 27, 16, 0), 'buyPirce': 55.54, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 28, 7, 2), 'sellPirce': 55.44, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d7093'), 'orderId': 3, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 27, 16, 11), 'buyPirce': 55.4, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 27, 2, 12), 'sellPirce': 55.37, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d7094'), 'orderId': 4, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 28, 7, 25), 'buyPirce': 55.71, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 26, 10, 27), 'sellPirce': 55.79, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d7095'), 'orderId': 5, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 26, 10, 35), 'buyPirce': 56.05, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 27, 16, 37), 'sellPirce': 56.07, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d7096'), 'orderId': 6, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 26, 10, 39), 'buyPirce': 56.07, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 26, 10, 41), 'sellPirce': 56.0, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d7097'), 'orderId': 7, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 27, 16, 57), 'buyPirce': 56.26, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 27, 17, 3), 'sellPirce': 56.18, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d7098'), 'orderId': 8, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 28, 10, 28), 'buyPirce': 56.18, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 26, 12, 37), 'sellPirce': 56.17, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d7099'), 'orderId': 9, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 28, 8, 51), 'buyPirce': 56.12, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 27, 2, 57), 'sellPirce': 56.18, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d709a'), 'orderId': 10, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 27, 3, 8), 'buyPirce': 56.29, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 27, 3, 10), 'sellPirce': 56.11, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d709b'), 'orderId': 11, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 27, 5, 9), 'buyPirce': 55.48, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 27, 21, 11), 'sellPirce': 55.51, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d709c'), 'orderId': 12, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 27, 20, 43), 'buyPirce': 55.62, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 26, 14, 45), 'sellPirce': 55.68, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d709d'), 'orderId': 13, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 27, 5, 53), 'buyPirce': 55.78, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 26, 14, 55), 'sellPirce': 55.7, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d709e'), 'orderId': 14, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 27, 6, 20), 'buyPirce': 55.69, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 28, 12, 20), 'sellPirce': 55.64, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d709f'), 'orderId': 15, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 27, 21, 52), 'buyPirce': 55.36, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 26, 15, 54), 'sellPirce': 55.37, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70a0'), 'orderId': 1, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 17, 9, 40), 'buyPirce': 48.57, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 18, 0, 42), 'sellPirce': 48.58, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70a1'), 'orderId': 2, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 18, 15, 42), 'buyPirce': 48.58, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 18, 15, 55), 'sellPirce': 48.16, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70a2'), 'orderId': 3, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 18, 15, 54), 'buyPirce': 48.14, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 17, 10, 9), 'sellPirce': 48.33, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70a3'), 'orderId': 4, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 18, 16, 5), 'buyPirce': 48.19, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 18, 16, 13), 'sellPirce': 48.32, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70a4'), 'orderId': 5, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 19, 7, 12), 'buyPirce': 48.21, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 18, 16, 17), 'sellPirce': 48.21, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70a5'), 'orderId': 6, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 19, 7, 15), 'buyPirce': 48.35, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 17, 10, 32), 'sellPirce': 48.42, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70a6'), 'orderId': 7, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 19, 7, 29), 'buyPirce': 48.42, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 18, 17, 9), 'sellPirce': 48.89, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70a7'), 'orderId': 8, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 19, 8, 7), 'buyPirce': 48.93, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 18, 17, 29), 'sellPirce': 49.06, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70a8'), 'orderId': 9, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 18, 2, 28), 'buyPirce': 49.04, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 19, 8, 43), 'sellPirce': 49.12, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70a9'), 'orderId': 10, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 19, 8, 42), 'buyPirce': 49.08, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 17, 11, 48), 'sellPirce': 49.08, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70aa'), 'orderId': 11, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 18, 17, 46), 'buyPirce': 49.15, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 17, 12, 4), 'sellPirce': 48.95, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70ab'), 'orderId': 12, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 18, 18, 3), 'buyPirce': 48.93, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 19, 9, 18), 'sellPirce': 48.93, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70ac'), 'orderId': 13, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 18, 5, 12), 'buyPirce': 48.9, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 18, 4, 9), 'sellPirce': 48.92, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70ad'), 'orderId': 14, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 19, 12, 6), 'buyPirce': 48.99, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 17, 13, 58), 'sellPirce': 48.48, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70ae'), 'orderId': 15, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 18, 19, 55), 'buyPirce': 48.46, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 18, 20, 6), 'sellPirce': 48.48, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70af'), 'orderId': 16, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 18, 20, 1), 'buyPirce': 48.49, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 19, 13, 29), 'sellPirce': 48.87, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70b0'), 'orderId': 17, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 18, 20, 27), 'buyPirce': 48.83, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 18, 20, 35), 'sellPirce': 48.98, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70b1'), 'orderId': 18, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 18, 6, 34), 'buyPirce': 48.91, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 17, 14, 50), 'sellPirce': 49.08, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70b2'), 'orderId': 19, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 18, 20, 41), 'buyPirce': 48.99, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 18, 6, 22), 'sellPirce': 48.9, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70b3'), 'orderId': 20, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 18, 6, 21), 'buyPirce': 48.95, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 18, 6, 53), 'sellPirce': 49.45, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70b6'), 'orderId': 1, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 11, 0, 39), 'buyPirce': 49.39, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 12, 6, 40), 'sellPirce': 49.28, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70b7'), 'orderId': 2, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 12, 6, 54), 'buyPirce': 49.02, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 11, 15, 57), 'sellPirce': 49.0, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70b8'), 'orderId': 3, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 11, 1, 1), 'buyPirce': 49.1, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 11, 1, 2), 'sellPirce': 49.0, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70b9'), 'orderId': 4, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 12, 7, 9), 'buyPirce': 48.98, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 11, 1, 12), 'sellPirce': 49.14, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70ba'), 'orderId': 5, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 10, 10, 15), 'buyPirce': 49.24, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 11, 1, 20), 'sellPirce': 49.2, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70bb'), 'orderId': 6, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 10, 10, 53), 'buyPirce': 49.55, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 12, 7, 55), 'sellPirce': 49.56, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70bc'), 'orderId': 7, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 11, 2, 24), 'buyPirce': 49.42, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 11, 17, 26), 'sellPirce': 49.48, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70bd'), 'orderId': 8, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 11, 17, 48), 'buyPirce': 49.5, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 10, 11, 50), 'sellPirce': 49.48, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70be'), 'orderId': 9, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 10, 13, 1), 'buyPirce': 49.73, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 11, 4, 2), 'sellPirce': 49.7, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70bf'), 'orderId': 10, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 11, 4, 18), 'buyPirce': 49.75, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 11, 19, 21), 'sellPirce': 49.7, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70c0'), 'orderId': 11, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 11, 20, 37), 'buyPirce': 49.76, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 11, 19, 38), 'sellPirce': 49.84, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70c1'), 'orderId': 12, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 11, 19, 48), 'buyPirce': 49.83, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 11, 6, 49), 'sellPirce': 49.84, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70c2'), 'orderId': 13, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 11, 20, 21), 'buyPirce': 50.16, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 11, 5, 29), 'sellPirce': 50.18, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
# {'_id': ObjectId('65c232baa7754967e40d70c3'), 'orderId': 14, 'robotId': 'xrob003', 'strategyId': 'xstg003', 'buyTime': datetime.datetime(2024, 1, 11, 6, 56), 'buyPirce': 49.94, 'buyCond': 'tf15s_hl', 'sellTime': datetime.datetime(2024, 1, 10, 15, 58), 'sellPirce': 50.0, 'sellCond': 'tf15s_lh_or_tf15s_ema12x<24'}
